# %%
# %load_ext autoreload
# %autoreload 2

from prepare import *
from CILC_helpers import CILC
from show import moview, Dl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nu = [22.8, 33.0, 40.7, 60.8, 93.5]
lmax = 1000
nside = 512

# %%
imaps =read_imap(lmax)
alms = map_to_alm(imaps, lmax)

# %%
alm_clean = CILC(alms, lmax, nu).do_CILC()

# %%
moview(alm_clean)

# %%
Dl(alm_clean, lmax)
